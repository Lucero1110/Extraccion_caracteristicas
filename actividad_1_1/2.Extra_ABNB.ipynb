# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
# Verificar sin indice 
df= pd.read_csv('Datos_Limpios_Athenas.csv')
df
# Out:
#        Unnamed: 0                   id    host_id  host_listings_count  \
# 0               0                27262      37177                  4.0
# 1               1               809874    4259738                  2.0
# 2               2               866381    4551671                  1.0
# 3               3               886724    4700824                  1.0
# 4               4               896212    4777984                 29.0
# ...           ...                  ...        ...                  ...
# 14637       14637  1318251942056598277   25811452                  3.0
# 14638       14638  1318276742106864141  666320836                  2.0
# 14639       14639  1318307768558324736  221534605                 53.0
# 14640       14640  1318405788507138933  650411545                  1.0
# 14641       14641  1318601800941001079   31290848                 11.0
#
#        host_total_listings_count   latitude  longitude  accommodates  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14642 entries, 0 to 14641
# Data columns (total 51 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    14642 non-null  int64
#  1   id                                            14642 non-null  int64
#  2   host_id                                       14642 non-null  int64
#  3   host_listings_count                           14642 non-null  float64
#  4   host_total_listings_count                     14642 non-null  float64
#  5   latitude                                      14642 non-null  float64
#  6   longitude                                     14642 non-null  float64
#  7   accommodates                                  14642 non-null  float64
#  8   bathrooms                                     14642 non-null  float64
# ...

# %%
#Obtengo un análisis univariado de las variables categoricas 
freq_tbl(df)
# Out:
#   last_scraped  frequency  percentage  cumulative_perc
# 0   2024-12-25      11668    0.796886         0.796886
# 1   2024-12-26       2973    0.203046         0.999932
# 2   2025-01-02          1    0.000068         1.000000
#
# ----------------------------------------------------------------
#
#             source  frequency  percentage  cumulative_perc
# 0      city scrape      13722    0.937167         0.937167
# 1  previous scrape        920    0.062833         1.000000
#
# ----------------------------------------------------------------
#
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour      11590    0.791559         0.791559
# 1    Dato desconocido       1739    0.118768         0.910326
# 2  within a few hours        778    0.053135         0.963461
# 3        within a day        393    0.026841         0.990302
# 4  a few days or more        142    0.009698         1.000000
#
# ...

# %% [markdown]
# ### Tablas categoricas en gráficos

# %% [markdown]
# **Tabla1**

# %%
table1 = freq_tbl(df['last_scraped'])
table1
# Out:
#   last_scraped  frequency  percentage  cumulative_perc
# 0   2024-12-25      11668    0.796886         0.796886
# 1   2024-12-26       2973    0.203046         0.999932
# 2   2025-01-02          1    0.000068         1.000000

# %%
#Eliminar columnas que no me importan 
table1 = table1.drop(['percentage', 'cumulative_perc'], axis=1)
table1
# Out:
#   last_scraped  frequency
# 0   2024-12-25      11668
# 1   2024-12-26       2973
# 2   2025-01-02          1

# %%
#Ppoenr index para que tome como datos lo que queremos gráficar 
filtro_index1 = table1.set_index('last_scraped')
filtro_index1
# Out:
#               frequency
# last_scraped
# 2024-12-25        11668
# 2024-12-26         2973
# 2025-01-02            1

# %%
filtro_index1.plot(kind = 'bar', width = 0.8, figsize=(10,4), color="pink")
plt.title('Última actualización')
plt.xlabel('fecha')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
filtro_index1.plot(kind='area', figsize =(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='last_scraped'>

# %%
filtro_index1['frequency'].plot(kind='pie', figsize =(10,4), shadow = True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **table 2**

# %%
table2 = freq_tbl(df['source'])
table2
# Out:
#             source  frequency  percentage  cumulative_perc
# 0      city scrape      13722    0.937167         0.937167
# 1  previous scrape        920    0.062833         1.000000

# %%
#Eliminar columnas que no me importan 
table2 = table2.drop(['percentage', 'cumulative_perc'], axis=1)
table2
# Out:
#             source  frequency
# 0      city scrape      13722
# 1  previous scrape        920

# %%
#Ppoenr index para que tome como datos lo que queremos gráficar 
filtro_index2 = table2.set_index('source')
filtro_index2
# Out:
#                  frequency
# source
# city scrape          13722
# previous scrape        920

# %%
filtro_index2.plot(kind = 'bar', width = 0.8, figsize=(10,4), color="pink")
plt.title('Fuente')
plt.xlabel('tipo de fuente')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
filtro_index2.plot(kind='area', figsize =(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='source'>

# %%
filtro_index2['frequency'].plot(kind='pie', figsize =(10,4), shadow = True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Table 3**

# %%
table3 = freq_tbl(df['host_response_time'])
table3
# Out:
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour      11590    0.791559         0.791559
# 1    Dato desconocido       1739    0.118768         0.910326
# 2  within a few hours        778    0.053135         0.963461
# 3        within a day        393    0.026841         0.990302
# 4  a few days or more        142    0.009698         1.000000

# %%
#Eliminar columnas que no me importan 
table3 = table3.drop(['percentage', 'cumulative_perc'], axis=1)
table3
# Out:
#    host_response_time  frequency
# 0      within an hour      11590
# 1    Dato desconocido       1739
# 2  within a few hours        778
# 3        within a day        393
# 4  a few days or more        142

# %%
#Ppoenr index para que tome como datos lo que queremos gráficar 
filtro_index3 = table3.set_index('host_response_time')
filtro_index3
# Out:
#                     frequency
# host_response_time
# within an hour          11590
# Dato desconocido         1739
# within a few hours        778
# within a day              393
# a few days or more        142

# %%
filtro_index3.plot(kind = 'bar', width = 0.8, figsize=(10,4), color="pink")
plt.title('Tiempo de respuesta')
plt.xlabel('tipo de Tiempo')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
filtro_index3.plot(kind='area', figsize =(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='host_response_time'>

# %%
filtro_index3['frequency'].plot(kind='pie', figsize =(15,10), shadow = True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Table 4**

# %%
table4 = freq_tbl(df['host_response_rate'])
table4
# Out:
#    host_response_rate  frequency  percentage  cumulative_perc
# 0                100%      11590    0.791559         0.791559
# 1    Dato desconocido       1739    0.118768         0.910326
# 2                 99%        224    0.015298         0.925625
# 3                 90%        150    0.010245         0.935869
# 4                  0%        106    0.007239         0.943109
# 5                 80%         97    0.006625         0.949734
# 6                 98%         95    0.006488         0.956222
# 7                 97%         65    0.004439         0.960661
# 8                 86%         65    0.004439         0.965100
# 9                 95%         60    0.004098         0.969198
# 10                93%         49    0.003347         0.972545
# 11                50%         43    0.002937         0.975481
# 12                88%         41    0.002800         0.978282
# 13                96%         35    0.002390         0.980672
# ...

# %%
#Filtrar las filas más relevantes 
table4 = table4[table4['frequency']>30]
table4
# Out:
#    host_response_rate  frequency  percentage  cumulative_perc
# 0                100%      11590    0.791559         0.791559
# 1    Dato desconocido       1739    0.118768         0.910326
# 2                 99%        224    0.015298         0.925625
# 3                 90%        150    0.010245         0.935869
# 4                  0%        106    0.007239         0.943109
# 5                 80%         97    0.006625         0.949734
# 6                 98%         95    0.006488         0.956222
# 7                 97%         65    0.004439         0.960661
# 8                 86%         65    0.004439         0.965100
# 9                 95%         60    0.004098         0.969198
# 10                93%         49    0.003347         0.972545
# 11                50%         43    0.002937         0.975481
# 12                88%         41    0.002800         0.978282
# 13                96%         35    0.002390         0.980672
# ...

# %%
#Eliminar columnas que no me importan 
table4 = table4.drop(['percentage', 'cumulative_perc'], axis=1)
table4
# Out:
#    host_response_rate  frequency
# 0                100%      11590
# 1    Dato desconocido       1739
# 2                 99%        224
# 3                 90%        150
# 4                  0%        106
# 5                 80%         97
# 6                 98%         95
# 7                 97%         65
# 8                 86%         65
# 9                 95%         60
# 10                93%         49
# 11                50%         43
# 12                88%         41
# 13                96%         35
# 14                89%         34
# 15                67%         31

# %%
#Ppoenr index para que tome como datos lo que queremos gráficar 
filtro_index4 = table4.set_index('host_response_rate')
filtro_index4
# Out:
#                     frequency
# host_response_rate
# 100%                    11590
# Dato desconocido         1739
# 99%                       224
# 90%                       150
# 0%                        106
# 80%                        97
# 98%                        95
# 97%                        65
# 86%                        65
# 95%                        60
# 93%                        49
# 50%                        43
# 88%                        41
# 96%                        35
# 89%                        34
# 67%                        31

# %%
filtro_index4.plot(kind = 'bar', width = 0.8, figsize=(15,10), color="pink")
plt.title('Tiempo de respuesta ')
plt.xlabel('Tiempo')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
filtro_index4.plot(kind='area', figsize =(15,10), alpha = 0.5)
# Out:
# <Axes: xlabel='host_response_rate'>

# %%
filtro_index4['frequency'].plot(kind='pie', figsize =(15,10), shadow = True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Table 5**

# %%
table5 = freq_tbl(df['host_acceptance_rate'])
table5
# Out:
#    host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                  100%       8781    0.599713         0.599713
# 1                   99%       1507    0.102923         0.702636
# 2      Dato desconocido        831    0.056755         0.759391
# 3                   98%        564    0.038519         0.797910
# 4                   97%        370    0.025270         0.823180
# ..                  ...        ...         ...              ...
# 81                  65%          1    0.000068         0.999727
# 82                  13%          1    0.000068         0.999795
# 83                  15%          1    0.000068         0.999863
# 84                  26%          1    0.000068         0.999932
# 85                  30%          1    0.000068         1.000000
#
# [86 rows x 4 columns]

# %%
#Eliminar columnas que no me importan 
table5 = table5.drop(['percentage', 'cumulative_perc'], axis=1)
table5
# Out:
#    host_acceptance_rate  frequency
# 0                  100%       8781
# 1                   99%       1507
# 2      Dato desconocido        831
# 3                   98%        564
# 4                   97%        370
# ..                  ...        ...
# 81                  65%          1
# 82                  13%          1
# 83                  15%          1
# 84                  26%          1
# 85                  30%          1
#
# [86 rows x 2 columns]

# %%
#Filtrar las filas más relevantes 
filtro = table5[table5['frequency']>50]
filtro
# Out:
#    host_acceptance_rate  frequency
# 0                  100%       8781
# 1                   99%       1507
# 2      Dato desconocido        831
# 3                   98%        564
# 4                   97%        370
# 5                    0%        258
# 6                   96%        240
# 7                   94%        222
# 8                   95%        210
# 9                   93%        152
# 10                  92%        147
# 11                  89%        105
# 12                  50%         94
# 13                  67%         77
# 14                  86%         68
# 15                  91%         66
# 16                  84%         63
# 17                  88%         54

# %%
#Ppoenr index para que tome como datos lo que queremos gráficar 
filtro_index = filtro.set_index('host_acceptance_rate')
filtro_index
# Out:
#                       frequency
# host_acceptance_rate
# 100%                       8781
# 99%                        1507
# Dato desconocido            831
# 98%                         564
# 97%                         370
# 0%                          258
# 96%                         240
# 94%                         222
# 95%                         210
# 93%                         152
# 92%                         147
# 89%                         105
# 50%                          94
# 67%                          77
# 86%                          68
# 91%                          66
# 84%                          63
# 88%                          54

# %%
filtro_index.plot(kind = 'bar', width = 0.8, figsize=(10,4), color="pink")
plt.title('Porcentajes en el que host acepta')
plt.xlabel('Host acceptance rate')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
filtro_index.plot(kind='area', figsize =(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='host_acceptance_rate'>

# %%
filtro_index['frequency'].plot(kind='pie', figsize =(10,4), shadow = True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Table 6**

# %%
table6 = freq_tbl(df['host_is_superhost'])
table6
# Out:
#   host_is_superhost  frequency  percentage  cumulative_perc
# 0                 f       8762    0.598416         0.598416
# 1                 t       5880    0.401584         1.000000

# %%
#Eliminar columnas que no me importan 
table6 = table6.drop(['percentage', 'cumulative_perc'], axis=1)
table6
# Out:
#   host_is_superhost  frequency
# 0                 f       8762
# 1                 t       5880

# %%
#Ppoenr index para que tome como datos lo que queremos gráficar 
filtro_index6 = table6.set_index('host_is_superhost')
filtro_index6
# Out:
#                    frequency
# host_is_superhost
# f                       8762
# t                       5880

# %%
filtro_index6.plot(kind = 'bar', width = 0.8, figsize=(10,4), color="pink")
plt.title('Host is super host')
plt.xlabel('Tipo de superhost')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
filtro_index6.plot(kind='area', figsize =(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='host_is_superhost'>

# %%
filtro_index6['frequency'].plot(kind='pie', figsize =(10,4), shadow = True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table7 = freq_tbl(df['host_verifications'])
table7
# Out:
#                  host_verifications  frequency  percentage  cumulative_perc
# 0                ['email', 'phone']      11604    0.792515         0.792515
# 1  ['email', 'phone', 'work_email']       1885    0.128739         0.921254
# 2                         ['phone']       1072    0.073214         0.994468
# 3           ['phone', 'work_email']         62    0.004234         0.998702
# 4                         ['email']         18    0.001229         0.999932
# 5                                []          1    0.000068         1.000000

# %% [markdown]
# **Table 7**

# %%
#Eliminar columnas que no me importan 
table7 = table7.drop(['percentage', 'cumulative_perc'], axis=1)
table7
# Out:
#                  host_verifications  frequency
# 0                ['email', 'phone']      11604
# 1  ['email', 'phone', 'work_email']       1885
# 2                         ['phone']       1072
# 3           ['phone', 'work_email']         62
# 4                         ['email']         18
# 5                                []          1

# %%
#Filtrar las filas más relevantes 
table7 = table7[table7['frequency']>1]
table7
# Out:
#                  host_verifications  frequency
# 0                ['email', 'phone']      11604
# 1  ['email', 'phone', 'work_email']       1885
# 2                         ['phone']       1072
# 3           ['phone', 'work_email']         62
# 4                         ['email']         18

# %%
#Ppoenr index para que tome como datos lo que queremos gráficar 
filtro_index7 = table7.set_index('host_verifications')
filtro_index7
# Out:
#                                   frequency
# host_verifications
# ['email', 'phone']                    11604
# ['email', 'phone', 'work_email']       1885
# ['phone']                              1072
# ['phone', 'work_email']                  62
# ['email']                                18

# %%
filtro_index7.plot(kind = 'bar', width = 0.8, figsize=(10,4), color="pink")
plt.title('Host_verifications')
plt.xlabel('Tipo de verificaciones')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
filtro_index7.plot(kind='area', figsize =(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='host_verifications'>

# %%
filtro_index7['frequency'].plot(kind='pie', figsize =(15,10), shadow = True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Table 8**

# %%
table8 = freq_tbl(df['neighbourhood'])
table8
# Out:
#                  neighbourhood  frequency  percentage  cumulative_perc
# 0             Dato desconocido       6944    0.474252         0.474252
# 1               Athina, Greece       6783    0.463256         0.937509
# 2               Athens, Greece        275    0.018782         0.956290
# 3       Athens, Attica, Greece        165    0.011269         0.967559
# 4       Athina, Athens, Greece         65    0.004439         0.971998
# ..                         ...        ...         ...              ...
# 158     Athina, Grecia, Greece          1    0.000068         0.999727
# 159  Athens, Acropolis, Greece          1    0.000068         0.999795
# 160     Αθήνα, Attikhs, Greece          1    0.000068         0.999863
# 161     Αθήνα, Attikis, Greece          1    0.000068         0.999932
# 162   Athens , Sepolia, Greece          1    0.000068         1.000000
#
# [163 rows x 4 columns]

# %%
#Eliminar columnas que no me importan 
table8 = table8.drop(['percentage', 'cumulative_perc'], axis=1)
table8
# Out:
#                  neighbourhood  frequency
# 0             Dato desconocido       6944
# 1               Athina, Greece       6783
# 2               Athens, Greece        275
# 3       Athens, Attica, Greece        165
# 4       Athina, Athens, Greece         65
# ..                         ...        ...
# 158     Athina, Grecia, Greece          1
# 159  Athens, Acropolis, Greece          1
# 160     Αθήνα, Attikhs, Greece          1
# 161     Αθήνα, Attikis, Greece          1
# 162   Athens , Sepolia, Greece          1
#
# [163 rows x 2 columns]

# %%
#Filtrar las filas más relevantes 
table8 = table8[table8['frequency']>50]
table8
# Out:
#             neighbourhood  frequency
# 0        Dato desconocido       6944
# 1          Athina, Greece       6783
# 2          Athens, Greece        275
# 3  Athens, Attica, Greece        165
# 4  Athina, Athens, Greece         65

# %%
#Ppoenr index para que tome como datos lo que queremos gráficar 
filtro_index8 = table8.set_index('neighbourhood')
filtro_index8
# Out:
#                         frequency
# neighbourhood
# Dato desconocido             6944
# Athina, Greece               6783
# Athens, Greece                275
# Athens, Attica, Greece        165
# Athina, Athens, Greece         65

# %%
filtro_index8.plot(kind = 'bar', width = 0.8, figsize=(10,4), color="pink")
plt.title('Colonia')
plt.xlabel('Tipo de colonia')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
filtro_index8.plot(kind='area', figsize =(10,4), alpha = 0.6)
# Out:
# <Axes: xlabel='neighbourhood'>

# %%
filtro_index8['frequency'].plot(kind='pie', figsize =(15,10), shadow = True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Table 9**

# %%
table9 = freq_tbl(df['property_type'])
table9
# Out:
#                          property_type  frequency  percentage  cumulative_perc
# 0                   Entire rental unit       9530    0.650867         0.650867
# 1                         Entire condo       2974    0.203114         0.853982
# 2          Private room in rental unit        419    0.028616         0.882598
# 3                          Entire home        406    0.027728         0.910326
# 4            Entire serviced apartment        268    0.018304         0.928630
# 5                        Room in hotel        231    0.015777         0.944407
# 6                          Entire loft        129    0.008810         0.953217
# 7                   Room in aparthotel        127    0.008674         0.961890
# 8                Private room in condo        125    0.008537         0.970428
# 9               Room in boutique hotel         88    0.006010         0.976438
# 10                Private room in home         46    0.003142         0.979579
# ...

# %%
#Eliminar columnas que no me importan 
table9 = table9.drop(['percentage', 'cumulative_perc'], axis=1)
table9
# Out:
#                          property_type  frequency
# 0                   Entire rental unit       9530
# 1                         Entire condo       2974
# 2          Private room in rental unit        419
# 3                          Entire home        406
# 4            Entire serviced apartment        268
# 5                        Room in hotel        231
# 6                          Entire loft        129
# 7                   Room in aparthotel        127
# 8                Private room in condo        125
# 9               Room in boutique hotel         88
# 10                Private room in home         46
# 11  Private room in serviced apartment         43
# 12                    Entire townhouse         30
# 13          Room in serviced apartment         27
# 14   Private room in bed and breakfast         23
# 15         Private room in guest suite         20
# 16                           Tiny home         18
# 17                        Entire villa         17
# ...

# %%
#Filtrar las filas más relevantes 
table9 = table9[table9['frequency']>100]
table9
# Out:
#                  property_type  frequency
# 0           Entire rental unit       9530
# 1                 Entire condo       2974
# 2  Private room in rental unit        419
# 3                  Entire home        406
# 4    Entire serviced apartment        268
# 5                Room in hotel        231
# 6                  Entire loft        129
# 7           Room in aparthotel        127
# 8        Private room in condo        125

# %%
#Ppoenr index para que tome como datos lo que queremos gráficar 
filtro_index9 = table9.set_index('property_type')
filtro_index9
# Out:
#                              frequency
# property_type
# Entire rental unit                9530
# Entire condo                      2974
# Private room in rental unit        419
# Entire home                        406
# Entire serviced apartment          268
# Room in hotel                      231
# Entire loft                        129
# Room in aparthotel                 127
# Private room in condo              125

# %%
filtro_index9.plot(kind = 'bar', width = 0.8, figsize=(10,4), color="pink")
plt.title('Propiedad')
plt.xlabel('Tipo de Propiedad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
filtro_index9.plot(kind='area', figsize =(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='property_type'>

# %%
filtro_index9['frequency'].plot(kind='pie', figsize =(15,10), shadow = True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
table10 = freq_tbl(df['room_type'])
table10
# Out:
#          room_type  frequency  percentage  cumulative_perc
# 0  Entire home/apt      13499    0.921937         0.921937
# 1     Private room       1068    0.072941         0.994878
# 2       Hotel room         62    0.004234         0.999112
# 3      Shared room         13    0.000888         1.000000

# %%
#Eliminar columnas que no me importan 
table10 = table10.drop(['percentage', 'cumulative_perc'], axis=1)
table10
# Out:
#          room_type  frequency
# 0  Entire home/apt      13499
# 1     Private room       1068
# 2       Hotel room         62
# 3      Shared room         13

# %%
#Ppoenr index para que tome como datos lo que queremos gráficar 
filtro_index10 = table10.set_index('room_type')
filtro_index10
# Out:
#                  frequency
# room_type
# Entire home/apt      13499
# Private room          1068
# Hotel room              62
# Shared room             13

# %%
filtro_index10.plot(kind = 'bar', width = 0.8, figsize=(15,10), color="pink")
plt.title('Preferncia de tipos de cuarto')
plt.xlabel('Tipo de cuarto')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
filtro_index10.plot(kind='area', figsize =(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='room_type'>

# %%
filtro_index10['frequency'].plot(kind='pie', figsize =(15,10), shadow = True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ### Tablas númericas a categoricas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14642 entries, 0 to 14641
# Data columns (total 51 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    14642 non-null  int64
#  1   id                                            14642 non-null  int64
#  2   host_id                                       14642 non-null  int64
#  3   host_listings_count                           14642 non-null  float64
#  4   host_total_listings_count                     14642 non-null  float64
#  5   latitude                                      14642 non-null  float64
#  6   longitude                                     14642 non-null  float64
#  7   accommodates                                  14642 non-null  float64
#  8   bathrooms                                     14642 non-null  float64
# ...

# %% [markdown]
# **Table 11**

# %%
df['price'].info()
n= 14642
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 14642 entries, 0 to 14641
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 14642 non-null  float64
# dtypes: float64(1)
# memory usage: 114.5 KB

# %%
maxp = df['price'].max()
minp = df['price'].min()

limitesp =[minp,maxp]
limitesp
# Out:
# [25.0, 175.0]

# %%
Rp = maxp-minp
Rp
# Out:
# 150.0

# %%
nip= 1+3.32*np.log10(n)
nip
# Out:
# 14.829793336357806

# %%
#ANCHO
I = Rp/nip
I
# Out:
# 10.114773456232125

# %%
#Ctegoización de variables 
#A los limites inferiore se le reat uno y a los superiores se le suma 1
intervalosp = np.linspace(24.9, 175.1, 15) #tiene que ser uno más de limite de lo que son 
intervalosp
# Out:
# array([ 24.9       ,  35.62857143,  46.35714286,  57.08571429,
#         67.81428571,  78.54285714,  89.27142857, 100.        ,
#        110.72857143, 121.45714286, 132.18571429, 142.91428571,
#        153.64285714, 164.37142857, 175.1       ])

# %%
Categoriasp = ['Económico Básico', 'conómico Plus', 'Accesible', 'Intermedio Bajo', 'Intermedio', 'Intermedio Alto', 'Estándar', 'Estándar Plus', 'Premium Básico', 'Premium', 'Premium Plus', 'Alta Gama Básico', 'Alta Gama', 'Alta Gama Exclusivo' ]

# %%
df['price']= pd.cut(x= df['price'], bins = intervalosp, labels= Categoriasp)
df['price']
# Out:
# 0                Premium
# 1          Estándar Plus
# 2        Intermedio Alto
# 3              Accesible
# 4        Intermedio Bajo
#               ...
# 14637       Premium Plus
# 14638    Intermedio Bajo
# 14639         Intermedio
# 14640      conómico Plus
# 14641         Intermedio
# Name: price, Length: 14642, dtype: category
# Categories (14, object): ['Económico Básico' < 'conómico Plus' < 'Accesible' < 'Intermedio Bajo' ... 'Premium Plus' < 'Alta Gama Básico' < 'Alta Gama' < 'Alta Gama Exclusivo']

# %%
table11 = freq_tbl(df['price'])
table11
# Out:
#                   price  frequency  percentage  cumulative_perc
# 0            Intermedio       3874    0.264581         0.264581
# 1             Accesible       1990    0.135910         0.400492
# 2         conómico Plus       1798    0.122797         0.523289
# 3       Intermedio Bajo       1563    0.106748         0.630037
# 4       Intermedio Alto       1071    0.073146         0.703183
# 5      Económico Básico       1030    0.070346         0.773528
# 6              Estándar        951    0.064950         0.838478
# 7        Premium Básico        520    0.035514         0.873993
# 8         Estándar Plus        488    0.033329         0.907321
# 9               Premium        399    0.027250         0.934572
# 10     Alta Gama Básico        299    0.020421         0.954992
# 11         Premium Plus        295    0.020148         0.975140
# 12            Alta Gama        188    0.012840         0.987980
# 13  Alta Gama Exclusivo        176    0.012020         1.000000

# %%
#Eliminar columnas que no me importan 
table11 = table11.drop(['percentage', 'cumulative_perc'], axis=1)
table11
# Out:
#                   price  frequency
# 0            Intermedio       3874
# 1             Accesible       1990
# 2         conómico Plus       1798
# 3       Intermedio Bajo       1563
# 4       Intermedio Alto       1071
# 5      Económico Básico       1030
# 6              Estándar        951
# 7        Premium Básico        520
# 8         Estándar Plus        488
# 9               Premium        399
# 10     Alta Gama Básico        299
# 11         Premium Plus        295
# 12            Alta Gama        188
# 13  Alta Gama Exclusivo        176

# %%
#Ppoenr index para que tome como datos lo que queremos gráficar 
filtro_index11 = table11.set_index('price')
filtro_index11
# Out:
#                      frequency
# price
# Intermedio                3874
# Accesible                 1990
# conómico Plus             1798
# Intermedio Bajo           1563
# Intermedio Alto           1071
# Económico Básico          1030
# Estándar                   951
# Premium Básico             520
# Estándar Plus              488
# Premium                    399
# Alta Gama Básico           299
# Premium Plus               295
# Alta Gama                  188
# Alta Gama Exclusivo        176

# %%
filtro_index11.plot(kind = 'bar', width = 0.8, figsize=(10,4), color="pink")
plt.title('Herramientas de relación con los clientes')
plt.xlabel('Tipo de precio')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
filtro_index11.plot(kind='area', figsize =(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='price'>

# %%
filtro_index11['frequency'].plot(kind='pie', figsize =(10,4), shadow = True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Table 12**

# %%
df['minimum_nights'].info()
nmn= 14642
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 14642 entries, 0 to 14641
# Series name: minimum_nights
# Non-Null Count  Dtype
# --------------  -----
# 14642 non-null  float64
# dtypes: float64(1)
# memory usage: 114.5 KB

# %%
maxmn = df['minimum_nights'].max()
minmn = df['minimum_nights'].min()

# %%
limitesmn =[minmn,maxmn]
limitesmn
# Out:
# [1.0, 3.0]

# %%
Rmn = maxmn-minmn
Rmn
# Out:
# 2.0

# %%
nimn= 1+3.32*np.log10(nmn)
nimn
# Out:
# 14.829793336357806

# %%
Imn = Rmn/nimn
Imn
# Out:
# 0.134863646083095

# %%
intervalosmn = np.linspace(0.9, 3.1, 15) #tiene que ser uno más de limite de lo que son
intervalosmn
# Out:
# array([0.9       , 1.05714286, 1.21428571, 1.37142857, 1.52857143,
#        1.68571429, 1.84285714, 2.        , 2.15714286, 2.31428571,
#        2.47142857, 2.62857143, 2.78571429, 2.94285714, 3.1       ])

# %%
categoriasmn =['Ultra Corta Estancia', 'Estancia Express', 'Estancia Muy Corta', 'Estancia Corta', 'Corta Plus', 'Corta Extendida', 'Corta Larga', 'Estándar', 'Estándar Plus', 'Media Estancia', 'Media Plus', 'Media Extendida', 'Larga Estancia Básica', 'Larga Estancia']

# %%
df['minimum_nights']= pd.cut(x= df['minimum_nights'], bins = intervalosmn, labels= categoriasmn)
df['minimum_nights']
# Out:
# 0        Ultra Corta Estancia
# 1                  Corta Plus
# 2                 Corta Larga
# 3              Larga Estancia
# 4                 Corta Larga
#                  ...
# 14637             Corta Larga
# 14638    Ultra Corta Estancia
# 14639              Corta Plus
# 14640    Ultra Corta Estancia
# 14641    Ultra Corta Estancia
# Name: minimum_nights, Length: 14642, dtype: category
# Categories (14, object): ['Ultra Corta Estancia' < 'Estancia Express' < 'Estancia Muy Corta' < 'Estancia Corta' ... 'Media Plus' < 'Media Extendida' < 'Larga Estancia Básica' < 'Larga Estancia']

# %%
table12 = freq_tbl(df['minimum_nights'])
table12
# Out:
#            minimum_nights  frequency  percentage  cumulative_perc
# 0    Ultra Corta Estancia       6571    0.448777         0.448777
# 1             Corta Larga       5480    0.374266         0.823043
# 2          Larga Estancia       1631    0.111392         0.934435
# 3              Corta Plus        960    0.065565         1.000000
# 4        Estancia Express          0    0.000000         1.000000
# 5      Estancia Muy Corta          0    0.000000         1.000000
# 6          Estancia Corta          0    0.000000         1.000000
# 7         Corta Extendida          0    0.000000         1.000000
# 8                Estándar          0    0.000000         1.000000
# 9           Estándar Plus          0    0.000000         1.000000
# 10         Media Estancia          0    0.000000         1.000000
# 11             Media Plus          0    0.000000         1.000000
# 12        Media Extendida          0    0.000000         1.000000
# ...

# %%
#Eliminar columnas que no me importan
table12 = table12.drop(['percentage', 'cumulative_perc'], axis=1)
table12
# Out:
#            minimum_nights  frequency
# 0    Ultra Corta Estancia       6571
# 1             Corta Larga       5480
# 2          Larga Estancia       1631
# 3              Corta Plus        960
# 4        Estancia Express          0
# 5      Estancia Muy Corta          0
# 6          Estancia Corta          0
# 7         Corta Extendida          0
# 8                Estándar          0
# 9           Estándar Plus          0
# 10         Media Estancia          0
# 11             Media Plus          0
# 12        Media Extendida          0
# 13  Larga Estancia Básica          0

# %%
#Filtrar las filas más relevantes 
table12 = table12[table12['frequency']>1]
table12
# Out:
#          minimum_nights  frequency
# 0  Ultra Corta Estancia       6571
# 1           Corta Larga       5480
# 2        Larga Estancia       1631
# 3            Corta Plus        960

# %%
filtro_index12 = table12.set_index('minimum_nights')
filtro_index12
# Out:
#                       frequency
# minimum_nights
# Ultra Corta Estancia       6571
# Corta Larga                5480
# Larga Estancia             1631
# Corta Plus                  960

# %%
filtro_index12.plot(kind = 'bar', width = 0.8, figsize=(10,4), color="pink")
plt.title('Herramientas de relación con los clientes')
plt.xlabel('Tipo de tiempo de noche')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
filtro_index12.plot(kind='area', figsize =(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='minimum_nights'>

# %%
filtro_index12['frequency'].plot(kind='pie', figsize =(10,4), shadow = True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Table13**

# %%
df['maximum_nights'].info()
nmm= 14642
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 14642 entries, 0 to 14641
# Series name: maximum_nights
# Non-Null Count  Dtype
# --------------  -----
# 14642 non-null  float64
# dtypes: float64(1)
# memory usage: 114.5 KB

# %%
maxmm = df['maximum_nights'].max()
minmm = df['maximum_nights'].min()

# %%
limitesmm =[minmm,maxmm]
limitesmm
# Out:
# [1.0, 1125.0]

# %%
Rmm = maxmm-minmm
Rmm
# Out:
# 1124.0

# %%
nimm= 1+3.32*np.log10(nmm)
nimm
# Out:
# 14.829793336357806

# %%
Imm = Rmm/nimm
Imm
# Out:
# 75.7933690986994

# %%
intervalosmm = np.linspace(0.9, 1125.1, 15) #tiene que ser uno más de limite de lo que son
intervalosmm
# Out:
# array([9.0000e-01, 8.1200e+01, 1.6150e+02, 2.4180e+02, 3.2210e+02,
#        4.0240e+02, 4.8270e+02, 5.6300e+02, 6.4330e+02, 7.2360e+02,
#        8.0390e+02, 8.8420e+02, 9.6450e+02, 1.0448e+03, 1.1251e+03])

# %%
catergoriasmm =['Ultra Corta', 'Muy Corta', 'Corta', 'Corta Plus', 'Media', 'Media Plus', 'Media Extendida', 'Larga', 'Larga Plus', 'Larga Extendida', 'Muy Larga', 'Extensa', 'Extensa Plus', 'Ultra Extensa']

# %%
df['maximum_nights']= pd.cut(x= df['maximum_nights'], bins = intervalosmm, labels= catergoriasmm)
df['maximum_nights']
# Out:
# 0        Ultra Extensa
# 1            Muy Corta
# 2            Muy Corta
# 3        Ultra Extensa
# 4                Media
#              ...
# 14637      Ultra Corta
# 14638            Media
# 14639    Ultra Extensa
# 14640            Media
# 14641            Media
# Name: maximum_nights, Length: 14642, dtype: category
# Categories (14, object): ['Ultra Corta' < 'Muy Corta' < 'Corta' < 'Corta Plus' ... 'Muy Larga' < 'Extensa' < 'Extensa Plus' < 'Ultra Extensa']

# %%
table13 = freq_tbl(df['maximum_nights'])
table13
# Out:
#      maximum_nights  frequency  percentage  cumulative_perc
# 0             Media       5960    0.407048         0.407048
# 1       Ultra Corta       3884    0.265264         0.672313
# 2     Ultra Extensa       3607    0.246346         0.918659
# 3         Muy Corta        680    0.046442         0.965100
# 4   Larga Extendida        201    0.013728         0.978828
# 5             Corta        174    0.011884         0.990712
# 6        Corta Plus         58    0.003961         0.994673
# 7      Extensa Plus         42    0.002868         0.997541
# 8        Larga Plus         17    0.001161         0.998702
# 9   Media Extendida          8    0.000546         0.999249
# 10            Larga          6    0.000410         0.999659
# 11       Media Plus          4    0.000273         0.999932
# 12          Extensa          1    0.000068         1.000000
# 13        Muy Larga          0    0.000000         1.000000

# %%
table13 = table13.drop(['percentage', 'cumulative_perc'], axis=1)
table13
# Out:
#      maximum_nights  frequency
# 0             Media       5960
# 1       Ultra Corta       3884
# 2     Ultra Extensa       3607
# 3         Muy Corta        680
# 4   Larga Extendida        201
# 5             Corta        174
# 6        Corta Plus         58
# 7      Extensa Plus         42
# 8        Larga Plus         17
# 9   Media Extendida          8
# 10            Larga          6
# 11       Media Plus          4
# 12          Extensa          1
# 13        Muy Larga          0

# %%
filtro_index13 = table13.set_index('maximum_nights')
filtro_index13
# Out:
#                  frequency
# maximum_nights
# Media                 5960
# Ultra Corta           3884
# Ultra Extensa         3607
# Muy Corta              680
# Larga Extendida        201
# Corta                  174
# Corta Plus              58
# Extensa Plus            42
# Larga Plus              17
# Media Extendida          8
# Larga                    6
# Media Plus               4
# Extensa                  1
# Muy Larga                0

# %%
#Filtrar las filas más relevantes 
table13 = table13[table13['frequency']>600]
table13
# Out:
#   maximum_nights  frequency
# 0          Media       5960
# 1    Ultra Corta       3884
# 2  Ultra Extensa       3607
# 3      Muy Corta        680

# %%
#Ppoenr index para que tome como datos lo que queremos gráficar
filtro_index13 = table13.set_index('maximum_nights')
filtro_index13
# Out:
#                 frequency
# maximum_nights
# Media                5960
# Ultra Corta          3884
# Ultra Extensa        3607
# Muy Corta             680

# %%
filtro_index13.plot(kind = 'bar', width = 0.8, figsize=(10,4), color="pink")
plt.title('Herramientas de relación con los clientes')
plt.xlabel('Tipo de nomches maximas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
filtro_index13.plot(kind='area', figsize =(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='maximum_nights'>

# %%
filtro_index13['frequency'].plot(kind='pie', figsize =(10,4), shadow = True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Table14**

# %%
df['availability_365'].info()
na= 14642
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 14642 entries, 0 to 14641
# Series name: availability_365
# Non-Null Count  Dtype
# --------------  -----
# 14642 non-null  float64
# dtypes: float64(1)
# memory usage: 114.5 KB

# %%
maxa = df['availability_365'].max()
mina = df['availability_365'].min()

# %%
limitesa =[mina,maxa]
limitesa
# Out:
# [93.0, 365.0]

# %%
Ra = maxa-mina
Ra
# Out:
# 272.0

# %%
nia= 1+3.32*np.log10(na)
nia
# Out:
# 14.829793336357806

# %%
Ia = Ra/nia

# %%
#A los limites inferiore se le reat uno y a los superiores se le suma 1
intervalosa = np.linspace(92.9, 365.1, 15) #tiene que ser uno más de limite de lo que son
intervalosa
# Out:
# array([ 92.9       , 112.34285714, 131.78571429, 151.22857143,
#        170.67142857, 190.11428571, 209.55714286, 229.        ,
#        248.44285714, 267.88571429, 287.32857143, 306.77142857,
#        326.21428571, 345.65714286, 365.1       ])

# %%
Categoriasa =['Baja Disponibilidad', 'Disponibilidad Limitada', 'Disponibilidad Reducida', 'Disponibilidad Moderada', 'Disponibilidad Media', 'Disponibilidad Estable', 'Disponibilidad Alta', 'Alta Disponibilidad Plus', 'Muy Alta Disponibilidad', 'Disponibilidad Extensa', 'Disponibilidad Extensa Plus', 'Disponibilidad Total', 'Disponibilidad Máxima', 'Full Año Disponible']

# %%
df['availability_365']= pd.cut(x= df['availability_365'], bins = intervalosa, labels=Categoriasa )
df['availability_365']
# Out:
# 0                Full Año Disponible
# 1              Disponibilidad Máxima
# 2            Disponibilidad Reducida
# 3                Full Año Disponible
# 4        Disponibilidad Extensa Plus
#                     ...
# 14637            Full Año Disponible
# 14638            Full Año Disponible
# 14639            Full Año Disponible
# 14640            Full Año Disponible
# 14641            Full Año Disponible
# Name: availability_365, Length: 14642, dtype: category
# Categories (14, object): ['Baja Disponibilidad' < 'Disponibilidad Limitada' < 'Disponibilidad Reducida' < 'Disponibilidad Moderada' ... 'Disponibilidad Extensa Plus' < 'Disponibilidad Total' < 'Disponibilidad Máxima' < 'Full Año Disponible']

# %%
table14 = freq_tbl(df['availability_365'])
table13
# Out:
#   maximum_nights  frequency
# 0          Media       5960
# 1    Ultra Corta       3884
# 2  Ultra Extensa       3607
# 3      Muy Corta        680

# %%
table14 = table14.drop(['percentage', 'cumulative_perc'], axis=1)
table14
# Out:
#                availability_365  frequency
# 0           Full Año Disponible       4308
# 1   Disponibilidad Extensa Plus       2711
# 2         Disponibilidad Máxima       1540
# 3       Muy Alta Disponibilidad       1139
# 4          Disponibilidad Total        895
# 5        Disponibilidad Extensa        840
# 6          Disponibilidad Media        701
# 7      Alta Disponibilidad Plus        623
# 8       Disponibilidad Moderada        429
# 9           Disponibilidad Alta        390
# 10       Disponibilidad Estable        344
# 11      Disponibilidad Reducida        275
# 12      Disponibilidad Limitada        257
# 13          Baja Disponibilidad        190

# %%
#Ppoenr index para que tome como datos lo que queremos gráficar
filtro_index14 = table14.set_index('availability_365')
filtro_index14
# Out:
#                              frequency
# availability_365
# Full Año Disponible               4308
# Disponibilidad Extensa Plus       2711
# Disponibilidad Máxima             1540
# Muy Alta Disponibilidad           1139
# Disponibilidad Total               895
# Disponibilidad Extensa             840
# Disponibilidad Media               701
# Alta Disponibilidad Plus           623
# Disponibilidad Moderada            429
# Disponibilidad Alta                390
# Disponibilidad Estable             344
# Disponibilidad Reducida            275
# Disponibilidad Limitada            257
# Baja Disponibilidad                190

# %%
filtro_index14.plot(kind = 'bar', width = 0.8, figsize=(10,4), color="pink")
plt.title('Herramientas de relación con los clientes')
plt.xlabel('Tipo de disponibilidad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
filtro_index14.plot(kind='area', figsize =(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='availability_365'>

# %%
filtro_index14['frequency'].plot(kind='pie', figsize =(10,4), shadow = True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Tables 15**

# %%
df['review_scores_accuracy'].info()
nra= 14642
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 14642 entries, 0 to 14641
# Series name: review_scores_accuracy
# Non-Null Count  Dtype
# --------------  -----
# 14642 non-null  float64
# dtypes: float64(1)
# memory usage: 114.5 KB

# %%
maxra = df['review_scores_accuracy'].max()
minra = df['review_scores_accuracy'].min()


limitesra =[minra,maxra]
limitesra
# Out:
# [4.72, 5.0]

# %%
Ra = maxra-minra
Ra
# Out:
# 0.28000000000000025

# %%
nira= 1+3.32*np.log10(nra)
nira
# Out:
# 14.829793336357806

# %%
#ANCHO
I = Ra/nira

# %%
intervalosra = np.linspace(4.71, 5.1, 15) #tiene que ser uno más de limite de lo que son
intervalosra
# Out:
# array([4.71      , 4.73785714, 4.76571429, 4.79357143, 4.82142857,
#        4.84928571, 4.87714286, 4.905     , 4.93285714, 4.96071429,
#        4.98857143, 5.01642857, 5.04428571, 5.07214286, 5.1       ])

# %%
Categoriasra=['Precisión Baja', 'Precisión Aceptable', 'Precisión Moderada', 'Precisión Media', 'Precisión Buena', 'Precisión Notable', 'Precisión Alta', 'Precisión Muy Alta', 'Precisión Excelente', 'Precisión Superior', 'Precisión Destacada', 'Precisión Excepcional', 'Precisión Óptima', 'Precisión Perfecta']

# %%
df['review_scores_accuracy']= pd.cut(x= df['review_scores_accuracy'], bins = intervalosra, labels= Categoriasra)
df['review_scores_accuracy']
# Out:
# 0             Precisión Alta
# 1         Precisión Superior
# 2         Precisión Superior
# 3             Precisión Alta
# 4        Precisión Excelente
#                 ...
# 14637         Precisión Alta
# 14638         Precisión Alta
# 14639         Precisión Alta
# 14640         Precisión Alta
# 14641         Precisión Alta
# Name: review_scores_accuracy, Length: 14642, dtype: category
# Categories (14, object): ['Precisión Baja' < 'Precisión Aceptable' < 'Precisión Moderada' < 'Precisión Media' ... 'Precisión Destacada' < 'Precisión Excepcional' < 'Precisión Óptima' < 'Precisión Perfecta']

# %%
table15 = freq_tbl(df['review_scores_accuracy'])
table15
# Out:
#    review_scores_accuracy  frequency  percentage  cumulative_perc
# 0          Precisión Alta       5803    0.396326         0.396326
# 1     Precisión Destacada       3304    0.225652         0.621978
# 2      Precisión Muy Alta       1088    0.074307         0.696285
# 3     Precisión Excelente       1022    0.069799         0.766084
# 4       Precisión Notable        738    0.050403         0.816487
# 5         Precisión Media        622    0.042481         0.858967
# 6         Precisión Buena        492    0.033602         0.892569
# 7     Precisión Aceptable        490    0.033465         0.926035
# 8      Precisión Moderada        450    0.030734         0.956768
# 9      Precisión Superior        424    0.028958         0.985726
# 10         Precisión Baja        209    0.014274         1.000000
# 11  Precisión Excepcional          0    0.000000         1.000000
# 12       Precisión Óptima          0    0.000000         1.000000
# ...

# %%
table15 = table15.drop(['percentage', 'cumulative_perc'], axis=1)
table15
# Out:
#    review_scores_accuracy  frequency
# 0          Precisión Alta       5803
# 1     Precisión Destacada       3304
# 2      Precisión Muy Alta       1088
# 3     Precisión Excelente       1022
# 4       Precisión Notable        738
# 5         Precisión Media        622
# 6         Precisión Buena        492
# 7     Precisión Aceptable        490
# 8      Precisión Moderada        450
# 9      Precisión Superior        424
# 10         Precisión Baja        209
# 11  Precisión Excepcional          0
# 12       Precisión Óptima          0
# 13     Precisión Perfecta          0

# %%
#Filtrar las filas más relevantes 
table15 = table15[table15['frequency']>1]
table15
# Out:
#    review_scores_accuracy  frequency
# 0          Precisión Alta       5803
# 1     Precisión Destacada       3304
# 2      Precisión Muy Alta       1088
# 3     Precisión Excelente       1022
# 4       Precisión Notable        738
# 5         Precisión Media        622
# 6         Precisión Buena        492
# 7     Precisión Aceptable        490
# 8      Precisión Moderada        450
# 9      Precisión Superior        424
# 10         Precisión Baja        209

# %%
#Ppoenr index para que tome como datos lo que queremos gráficar
filtro_index15 = table15.set_index('review_scores_accuracy')
filtro_index15
# Out:
#                         frequency
# review_scores_accuracy
# Precisión Alta               5803
# Precisión Destacada          3304
# Precisión Muy Alta           1088
# Precisión Excelente          1022
# Precisión Notable             738
# Precisión Media               622
# Precisión Buena               492
# Precisión Aceptable           490
# Precisión Moderada            450
# Precisión Superior            424
# Precisión Baja                209

# %%
filtro_index15.plot(kind = 'bar', width = 0.8, figsize=(10,4), color="pink")
plt.title('Herramientas de relación con los clientes')
plt.xlabel('Tipo de precisión')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
filtro_index15.plot(kind='area', figsize =(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='review_scores_accuracy'>

# %%
filtro_index15['frequency'].plot(kind='pie', figsize =(15,10), shadow = True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Table16**

# %%
df['review_scores_cleanliness'].info()
nrc= 14642
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 14642 entries, 0 to 14641
# Series name: review_scores_cleanliness
# Non-Null Count  Dtype
# --------------  -----
# 14642 non-null  float64
# dtypes: float64(1)
# memory usage: 114.5 KB

# %%
maxrc = df['review_scores_cleanliness'].max()
minrc = df['review_scores_cleanliness'].min()
limitesrc =[minrc,maxrc]
limitesrc
# Out:
# [4.66, 5.0]

# %%
Rc= maxrc-minrc
Rc
nirc= 1+3.32*np.log10(nrc)
nirc


#ANCHO
I = Rc/nirc
I
# Out:
# 0.022926819834126144

# %%
intervalosrc = np.linspace(4.65, 5.1, 15) #tiene que ser uno más de limite de lo que son
intervalosrc
# Out:
# array([4.65      , 4.68214286, 4.71428571, 4.74642857, 4.77857143,
#        4.81071429, 4.84285714, 4.875     , 4.90714286, 4.93928571,
#        4.97142857, 5.00357143, 5.03571429, 5.06785714, 5.1       ])

# %%
categoriasrc=['Baja Limpieza', 'Limpieza Aceptable', 'Limpieza Moderada', 'Limpieza Media', 'Limpieza Buena', 'Limpieza Notable', 'Limpieza Alta', 'Limpieza Muy Alta', 'Limpieza Excelente', 'Limpieza Superior', 'Limpieza Destacada', 'Limpieza Excepcional', 'Limpieza Óptima', 'Limpieza Perfecta']

# %%
df['review_scores_cleanliness']= pd.cut(x= df['review_scores_cleanliness'], bins = intervalosrc, labels= categoriasrc)
df['review_scores_cleanliness']
# Out:
# 0         Limpieza Muy Alta
# 1         Limpieza Superior
# 2        Limpieza Destacada
# 3         Limpieza Muy Alta
# 4         Limpieza Superior
#                 ...
# 14637     Limpieza Muy Alta
# 14638     Limpieza Muy Alta
# 14639     Limpieza Muy Alta
# 14640     Limpieza Muy Alta
# 14641     Limpieza Muy Alta
# Name: review_scores_cleanliness, Length: 14642, dtype: category
# Categories (14, object): ['Baja Limpieza' < 'Limpieza Aceptable' < 'Limpieza Moderada' < 'Limpieza Media' ... 'Limpieza Destacada' < 'Limpieza Excepcional' < 'Limpieza Óptima' < 'Limpieza Perfecta']

# %%
table16 = freq_tbl(df['review_scores_cleanliness'])
table16
# Out:
#    review_scores_cleanliness  frequency  percentage  cumulative_perc
# 0          Limpieza Muy Alta       5524    0.377271         0.377271
# 1         Limpieza Destacada       3594    0.245458         0.622729
# 2          Limpieza Superior       1204    0.082229         0.704958
# 3         Limpieza Excelente        903    0.061672         0.766630
# 4             Limpieza Buena        658    0.044939         0.811569
# 5              Limpieza Alta        654    0.044666         0.856235
# 6           Limpieza Notable        563    0.038451         0.894687
# 7             Limpieza Media        534    0.036470         0.931157
# 8              Baja Limpieza        416    0.028411         0.959568
# 9         Limpieza Aceptable        316    0.021582         0.981150
# 10         Limpieza Moderada        276    0.018850         1.000000
# 11      Limpieza Excepcional          0    0.000000         1.000000
# 12           Limpieza Óptima          0    0.000000         1.000000
# ...

# %%
table16 = table16.drop(['percentage', 'cumulative_perc'], axis=1)
table16
# Out:
#    review_scores_cleanliness  frequency
# 0          Limpieza Muy Alta       5524
# 1         Limpieza Destacada       3594
# 2          Limpieza Superior       1204
# 3         Limpieza Excelente        903
# 4             Limpieza Buena        658
# 5              Limpieza Alta        654
# 6           Limpieza Notable        563
# 7             Limpieza Media        534
# 8              Baja Limpieza        416
# 9         Limpieza Aceptable        316
# 10         Limpieza Moderada        276
# 11      Limpieza Excepcional          0
# 12           Limpieza Óptima          0
# 13         Limpieza Perfecta          0

# %%
#Filtrar las filas más relevantes 
table16 = table16[table16['frequency']>10]
table16
# Out:
#    review_scores_cleanliness  frequency
# 0          Limpieza Muy Alta       5524
# 1         Limpieza Destacada       3594
# 2          Limpieza Superior       1204
# 3         Limpieza Excelente        903
# 4             Limpieza Buena        658
# 5              Limpieza Alta        654
# 6           Limpieza Notable        563
# 7             Limpieza Media        534
# 8              Baja Limpieza        416
# 9         Limpieza Aceptable        316
# 10         Limpieza Moderada        276

# %%
filtro_index16 = table16.set_index('review_scores_cleanliness')
filtro_index16
# Out:
#                            frequency
# review_scores_cleanliness
# Limpieza Muy Alta               5524
# Limpieza Destacada              3594
# Limpieza Superior               1204
# Limpieza Excelente               903
# Limpieza Buena                   658
# Limpieza Alta                    654
# Limpieza Notable                 563
# Limpieza Media                   534
# Baja Limpieza                    416
# Limpieza Aceptable               316
# Limpieza Moderada                276

# %%
filtro_index16.plot(kind = 'bar', width = 0.8, figsize=(10,4), color="pink")
plt.title('Herramientas de relación con los clientes')
plt.xlabel('Tipo de puntaje en limpieza')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
filtro_index16.plot(kind='area', figsize =(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='review_scores_cleanliness'>

# %%
filtro_index16['frequency'].plot(kind='pie', figsize =(15,10), shadow = True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Table 17**

# %%
df['review_scores_checkin'].info()
nsc= 14642
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 14642 entries, 0 to 14641
# Series name: review_scores_checkin
# Non-Null Count  Dtype
# --------------  -----
# 14642 non-null  float64
# dtypes: float64(1)
# memory usage: 114.5 KB

# %%
maxsc = df['review_scores_checkin'].max()
minsc= df['review_scores_checkin'].min()
limitessc =[minsc,maxsc]
limitessc
# Out:
# [4.81, 5.0]

# %%
Rsc = maxsc-minsc
Rsc
nisc= 1+3.32*np.log10(nsc)
nisc


#ANCHO
Isc = Rsc/nisc
Isc
# Out:
# 0.012812046377894053

# %%
#A los limites inferiore se le reat uno y a los superiores se le suma 1
intervalossc = np.linspace(4.80, 5.1, 15) #tiene que ser uno más de limite de lo que son
intervalossc
# Out:
# array([4.8       , 4.82142857, 4.84285714, 4.86428571, 4.88571429,
#        4.90714286, 4.92857143, 4.95      , 4.97142857, 4.99285714,
#        5.01428571, 5.03571429, 5.05714286, 5.07857143, 5.1       ])

# %%
Categoriassc =['Bajo Check-in', 'Check-in Aceptable', 'Check-in Moderado', 'Check-in Media', 'Check-in Bueno', 'Check-in Notable', 'Check-in Alto', 'Check-in Muy Alto', 'Check-in Excelente', 'Check-in Superior', 'Check-in Destacado', 'Check-in Excepcional', 'Check-in Óptimo', 'Check-in Perfecto']

# %%
df['review_scores_checkin']= pd.cut(x= df['review_scores_checkin'], bins = intervalossc, labels= Categoriassc)
df['review_scores_checkin']
# Out:
# 0        Check-in Moderado
# 1           Check-in Bueno
# 2            Check-in Alto
# 3           Check-in Media
# 4        Check-in Muy Alto
#                ...
# 14637       Check-in Bueno
# 14638       Check-in Bueno
# 14639       Check-in Bueno
# 14640       Check-in Bueno
# 14641       Check-in Bueno
# Name: review_scores_checkin, Length: 14642, dtype: category
# Categories (14, object): ['Bajo Check-in' < 'Check-in Aceptable' < 'Check-in Moderado' < 'Check-in Media' ... 'Check-in Destacado' < 'Check-in Excepcional' < 'Check-in Óptimo' < 'Check-in Perfecto']

# %%
table17 = freq_tbl(df['review_scores_checkin'])
table17
# Out:
#    review_scores_checkin  frequency  percentage  cumulative_perc
# 0         Check-in Bueno       5408    0.369348         0.369348
# 1      Check-in Superior       3966    0.270865         0.640213
# 2      Check-in Muy Alto       1373    0.093771         0.733984
# 3          Check-in Alto        928    0.063379         0.797364
# 4       Check-in Notable        802    0.054774         0.852138
# 5         Check-in Media        538    0.036744         0.888881
# 6     Check-in Excelente        513    0.035036         0.923917
# 7      Check-in Moderado        461    0.031485         0.955402
# 8     Check-in Aceptable        385    0.026294         0.981696
# 9          Bajo Check-in        268    0.018304         1.000000
# 10    Check-in Destacado          0    0.000000         1.000000
# 11  Check-in Excepcional          0    0.000000         1.000000
# 12       Check-in Óptimo          0    0.000000         1.000000
# ...

# %%
table17 = table17.drop(['percentage', 'cumulative_perc'], axis=1)
table17
# Out:
#    review_scores_checkin  frequency
# 0         Check-in Bueno       5408
# 1      Check-in Superior       3966
# 2      Check-in Muy Alto       1373
# 3          Check-in Alto        928
# 4       Check-in Notable        802
# 5         Check-in Media        538
# 6     Check-in Excelente        513
# 7      Check-in Moderado        461
# 8     Check-in Aceptable        385
# 9          Bajo Check-in        268
# 10    Check-in Destacado          0
# 11  Check-in Excepcional          0
# 12       Check-in Óptimo          0
# 13     Check-in Perfecto          0

# %%
#Filtrar las filas más relevantes 
table17 = table17[table17['frequency']>1]
table17
# Out:
#   review_scores_checkin  frequency
# 0        Check-in Bueno       5408
# 1     Check-in Superior       3966
# 2     Check-in Muy Alto       1373
# 3         Check-in Alto        928
# 4      Check-in Notable        802
# 5        Check-in Media        538
# 6    Check-in Excelente        513
# 7     Check-in Moderado        461
# 8    Check-in Aceptable        385
# 9         Bajo Check-in        268

# %%
filtro_index17 = table17.set_index('review_scores_checkin')
filtro_index17
# Out:
#                        frequency
# review_scores_checkin
# Check-in Bueno              5408
# Check-in Superior           3966
# Check-in Muy Alto           1373
# Check-in Alto                928
# Check-in Notable             802
# Check-in Media               538
# Check-in Excelente           513
# Check-in Moderado            461
# Check-in Aceptable           385
# Bajo Check-in                268

# %%
filtro_index17.plot(kind = 'bar', width = 0.8, figsize=(10,4), color="pink")
plt.title('Herramientas de relación con los clientes')
plt.xlabel('Tipo de puntaje en check-in')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
filtro_index17.plot(kind='area', figsize =(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='review_scores_checkin'>

# %%
filtro_index17['frequency'].plot(kind='pie', figsize =(15,10), shadow = True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Table18**

# %%
df['review_scores_communication'].info()
ncm= 14642
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 14642 entries, 0 to 14641
# Series name: review_scores_communication
# Non-Null Count  Dtype
# --------------  -----
# 14642 non-null  float64
# dtypes: float64(1)
# memory usage: 114.5 KB

# %%
maxcm = df['review_scores_communication'].max()
mincm = df['review_scores_communication'].min()
limitescm =[mincm,maxcm]
limitescm
# Out:
# [4.52, 5.0]

# %%
Rcm = maxcm-mincm
nicm= 1+3.32*np.log10(ncm)
#ANCHO
Icm = Rcm/nicm

# %%
intervaloscm = np.linspace(4.51, 5.1, 15) #tiene que ser uno más de limite de lo que son
intervaloscm
# Out:
# array([4.51      , 4.55214286, 4.59428571, 4.63642857, 4.67857143,
#        4.72071429, 4.76285714, 4.805     , 4.84714286, 4.88928571,
#        4.93142857, 4.97357143, 5.01571429, 5.05785714, 5.1       ])

# %%
Categoriascm =['Comunicación Baja', 'Comunicación Aceptable', 'Comunicación Moderada', 'Comunicación Media', 'Comunicación Buena', 'Comunicación Notable', 'Comunicación Alta', 'Comunicación Muy Alta', 'Comunicación Excelente', 'Comunicación Superior', 'Comunicación Destacada', 'Comunicación Excepcional', 'Comunicación Óptima', 'Comunicación Perfecta']

# %%
df['review_scores_communication']= pd.cut(x= df['review_scores_communication'], bins = intervaloscm, labels= Categoriascm)
df['review_scores_communication']
# Out:
# 0        Comunicación Destacada
# 1         Comunicación Superior
# 2         Comunicación Superior
# 3         Comunicación Superior
# 4         Comunicación Superior
#                   ...
# 14637     Comunicación Superior
# 14638     Comunicación Superior
# 14639     Comunicación Superior
# 14640     Comunicación Superior
# 14641     Comunicación Superior
# Name: review_scores_communication, Length: 14642, dtype: category
# Categories (14, object): ['Comunicación Baja' < 'Comunicación Aceptable' < 'Comunicación Moderada' < 'Comunicación Media' ... 'Comunicación Destacada' < 'Comunicación Excepcional' < 'Comunicación Óptima' < 'Comunicación Perfecta']

# %%
table18 = freq_tbl(df['review_scores_communication'])
table18
# Out:
#    review_scores_communication  frequency  percentage  cumulative_perc
# 0     Comunicación Excepcional       5176    0.353504         0.353504
# 1        Comunicación Superior       4718    0.322224         0.675727
# 2       Comunicación Destacada       1839    0.125598         0.801325
# 3       Comunicación Excelente        798    0.054501         0.855826
# 4        Comunicación Muy Alta        544    0.037153         0.892979
# 5            Comunicación Alta        465    0.031758         0.924737
# 6         Comunicación Notable        342    0.023357         0.948095
# 7           Comunicación Media        266    0.018167         0.966261
# 8           Comunicación Buena        242    0.016528         0.982789
# 9        Comunicación Moderada        119    0.008127         0.990917
# 10      Comunicación Aceptable         77    0.005259         0.996175
# 11           Comunicación Baja         56    0.003825         1.000000
# ...

# %%
table18 = table18.drop(['percentage', 'cumulative_perc'], axis=1)
table18
# Out:
#    review_scores_communication  frequency
# 0     Comunicación Excepcional       5176
# 1        Comunicación Superior       4718
# 2       Comunicación Destacada       1839
# 3       Comunicación Excelente        798
# 4        Comunicación Muy Alta        544
# 5            Comunicación Alta        465
# 6         Comunicación Notable        342
# 7           Comunicación Media        266
# 8           Comunicación Buena        242
# 9        Comunicación Moderada        119
# 10      Comunicación Aceptable         77
# 11           Comunicación Baja         56
# 12         Comunicación Óptima          0
# 13       Comunicación Perfecta          0

# %%
#Filtrar las filas más relevantes 
table18 = table18[table18['frequency']>100]

# %%
filtro_index18 = table18.set_index('review_scores_communication')
filtro_index18
# Out:
#                              frequency
# review_scores_communication
# Comunicación Excepcional          5176
# Comunicación Superior             4718
# Comunicación Destacada            1839
# Comunicación Excelente             798
# Comunicación Muy Alta              544
# Comunicación Alta                  465
# Comunicación Notable               342
# Comunicación Media                 266
# Comunicación Buena                 242
# Comunicación Moderada              119

# %%
filtro_index18.plot(kind = 'bar', width = 0.8, figsize=(10,4), color="pink")
plt.title('Herramientas de relación con los clientes')
plt.xlabel('Tipo de comuniación ')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
filtro_index18.plot(kind='area', figsize =(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='review_scores_communication'>

# %%
filtro_index18['frequency'].plot(kind='pie', figsize =(15,10), shadow = True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Table19**

# %%
df['review_scores_location'].info()
nsl= 14642
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 14642 entries, 0 to 14641
# Series name: review_scores_location
# Non-Null Count  Dtype
# --------------  -----
# 14642 non-null  float64
# dtypes: float64(1)
# memory usage: 114.5 KB

# %%
maxsl = df['review_scores_location'].max()
minsl = df['review_scores_location'].min()
limitessl =[minsl,maxsl]
limitessl
# Out:
# [3.94, 5.0]

# %%
Rsl = maxsl-minsl
nisl= 1+3.32*np.log10(nsl)
#ANCHO
Isl = Rsl/nisl

# %%
intervalosl = np.linspace(3.93, 5.1, 15) #tiene que ser uno más de limite de lo que son
intervalosl
# Out:
# array([3.93      , 4.01357143, 4.09714286, 4.18071429, 4.26428571,
#        4.34785714, 4.43142857, 4.515     , 4.59857143, 4.68214286,
#        4.76571429, 4.84928571, 4.93285714, 5.01642857, 5.1       ])

# %%
Categoriassl =['Ubicación Muy Baja', 'Ubicación Baja', 'Ubicación Aceptable', 'Ubicación Moderada', 'Ubicación Media', 'Ubicación Buena', 'Ubicación Notable', 'Ubicación Alta', 'Ubicación Muy Alta', 'Ubicación Excelente', 'Ubicación Superior', 'Ubicación Destacada', 'Ubicación Excepcional', 'Ubicación Perfecta']

# %%
df['review_scores_location']= pd.cut(x= df['review_scores_location'], bins = intervalosl, labels= Categoriassl)
df['review_scores_location']
# Out:
# 0        Ubicación Excelente
# 1        Ubicación Destacada
# 2        Ubicación Excelente
# 3            Ubicación Media
# 4         Ubicación Superior
#                 ...
# 14637     Ubicación Superior
# 14638     Ubicación Superior
# 14639     Ubicación Superior
# 14640     Ubicación Superior
# 14641     Ubicación Superior
# Name: review_scores_location, Length: 14642, dtype: category
# Categories (14, object): ['Ubicación Muy Baja' < 'Ubicación Baja' < 'Ubicación Aceptable' < 'Ubicación Moderada' ... 'Ubicación Superior' < 'Ubicación Destacada' < 'Ubicación Excepcional' < 'Ubicación Perfecta']

# %%
table19 = freq_tbl(df['review_scores_location'])
table19
# Out:
#    review_scores_location  frequency  percentage  cumulative_perc
# 0      Ubicación Superior       4208    0.287392         0.287392
# 1   Ubicación Excepcional       3756    0.256522         0.543915
# 2     Ubicación Destacada       1953    0.133383         0.677298
# 3     Ubicación Excelente       1125    0.076834         0.754132
# 4      Ubicación Muy Alta       1003    0.068502         0.822634
# 5       Ubicación Notable        607    0.041456         0.864090
# 6          Ubicación Alta        497    0.033943         0.898033
# 7         Ubicación Buena        351    0.023972         0.922005
# 8      Ubicación Muy Baja        333    0.022743         0.944748
# 9         Ubicación Media        333    0.022743         0.967491
# 10     Ubicación Moderada        230    0.015708         0.983199
# 11    Ubicación Aceptable        169    0.011542         0.994741
# 12         Ubicación Baja         77    0.005259         1.000000
# ...

# %%
table19 = table19.drop(['percentage', 'cumulative_perc'], axis=1)
table19
# Out:
#    review_scores_location  frequency
# 0      Ubicación Superior       4208
# 1   Ubicación Excepcional       3756
# 2     Ubicación Destacada       1953
# 3     Ubicación Excelente       1125
# 4      Ubicación Muy Alta       1003
# 5       Ubicación Notable        607
# 6          Ubicación Alta        497
# 7         Ubicación Buena        351
# 8      Ubicación Muy Baja        333
# 9         Ubicación Media        333
# 10     Ubicación Moderada        230
# 11    Ubicación Aceptable        169
# 12         Ubicación Baja         77
# 13     Ubicación Perfecta          0

# %%
#Filtrar las filas más relevantes 
table19 = table19[table19['frequency']>1]
table19
# Out:
#    review_scores_location  frequency
# 0      Ubicación Superior       4208
# 1   Ubicación Excepcional       3756
# 2     Ubicación Destacada       1953
# 3     Ubicación Excelente       1125
# 4      Ubicación Muy Alta       1003
# 5       Ubicación Notable        607
# 6          Ubicación Alta        497
# 7         Ubicación Buena        351
# 8      Ubicación Muy Baja        333
# 9         Ubicación Media        333
# 10     Ubicación Moderada        230
# 11    Ubicación Aceptable        169
# 12         Ubicación Baja         77

# %%
filtro_index19 = table19.set_index('review_scores_location')
filtro_index19
# Out:
#                         frequency
# review_scores_location
# Ubicación Superior           4208
# Ubicación Excepcional        3756
# Ubicación Destacada          1953
# Ubicación Excelente          1125
# Ubicación Muy Alta           1003
# Ubicación Notable             607
# Ubicación Alta                497
# Ubicación Buena               351
# Ubicación Muy Baja            333
# Ubicación Media               333
# Ubicación Moderada            230
# Ubicación Aceptable           169
# Ubicación Baja                 77

# %%
filtro_index19.plot(kind = 'bar', width = 0.8, figsize=(10,4), color="pink")
plt.title('Herramientas de relación con los clientes')
plt.xlabel('Tipo de locación')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
filtro_index19.plot(kind='area', figsize =(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='review_scores_location'>

# %%
filtro_index19['frequency'].plot(kind='pie', figsize =(15,10), shadow = True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **Table20**

# %%
df['review_scores_value'].info()
nsv= 14642
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 14642 entries, 0 to 14641
# Series name: review_scores_value
# Non-Null Count  Dtype
# --------------  -----
# 14642 non-null  float64
# dtypes: float64(1)
# memory usage: 114.5 KB

# %%
maxsv = df['review_scores_value'].max()
minsv = df['review_scores_value'].min()
limitessv =[minsv,maxsv]
limitessv
# Out:
# [4.23, 5.0]

# %%
Rsv = maxsv-minsv
nisv= 1+3.32*np.log10(nsv)
#ANCHO
Isv = Rsv/nisv

# %%
intervalossv = np.linspace(4.22, 5.1, 15) #tiene que ser uno más de limite de lo que son
intervalossv
# Out:
# array([4.22      , 4.28285714, 4.34571429, 4.40857143, 4.47142857,
#        4.53428571, 4.59714286, 4.66      , 4.72285714, 4.78571429,
#        4.84857143, 4.91142857, 4.97428571, 5.03714286, 5.1       ])

# %%
Categoriasv =['Valor Muy Bajo', 'Valor Bajo', 'Valor Aceptable', 'Valor Moderado', 'Valor Medio', 'Valor Bueno', 'Valor Notable', 'Valor Alto', 'Valor Muy Alto', 'Valor Excelente', 'Valor Superior', 'Valor Destacado', 'Valor Excepcional', 'Valor Perfecto']

# %%
df['review_scores_value']= pd.cut(x= df['review_scores_value'], bins = intervalossv, labels= Categoriasv)
df['review_scores_value']
# Out:
# 0             Valor Alto
# 1         Valor Superior
# 2         Valor Superior
# 3             Valor Alto
# 4        Valor Destacado
#               ...
# 14637    Valor Excelente
# 14638    Valor Excelente
# 14639    Valor Excelente
# 14640    Valor Excelente
# 14641    Valor Excelente
# Name: review_scores_value, Length: 14642, dtype: category
# Categories (14, object): ['Valor Muy Bajo' < 'Valor Bajo' < 'Valor Aceptable' < 'Valor Moderado' ... 'Valor Superior' < 'Valor Destacado' < 'Valor Excepcional' < 'Valor Perfecto']

# %%
table20 = freq_tbl(df['review_scores_value'])
table20
# Out:
#    review_scores_value  frequency  percentage  cumulative_perc
# 0      Valor Excelente       4729    0.322975         0.322975
# 1    Valor Excepcional       2390    0.163229         0.486204
# 2       Valor Superior       2023    0.138164         0.624368
# 3       Valor Muy Alto       1280    0.087420         0.711788
# 4      Valor Destacado       1143    0.078063         0.789851
# 5           Valor Alto       1015    0.069321         0.859172
# 6        Valor Notable        607    0.041456         0.900628
# 7          Valor Medio        468    0.031963         0.932591
# 8          Valor Bueno        361    0.024655         0.957246
# 9       Valor Moderado        222    0.015162         0.972408
# 10          Valor Bajo        181    0.012362         0.984770
# 11     Valor Aceptable        150    0.010245         0.995014
# 12      Valor Muy Bajo         73    0.004986         1.000000
# 13      Valor Perfecto          0    0.000000         1.000000

# %%
table20 = table20.drop(['percentage', 'cumulative_perc'], axis=1)
table20
# Out:
#    review_scores_value  frequency
# 0      Valor Excelente       4729
# 1    Valor Excepcional       2390
# 2       Valor Superior       2023
# 3       Valor Muy Alto       1280
# 4      Valor Destacado       1143
# 5           Valor Alto       1015
# 6        Valor Notable        607
# 7          Valor Medio        468
# 8          Valor Bueno        361
# 9       Valor Moderado        222
# 10          Valor Bajo        181
# 11     Valor Aceptable        150
# 12      Valor Muy Bajo         73
# 13      Valor Perfecto          0

# %%
#Filtrar las filas más relevantes 
table20 = table20[table20['frequency']>1]
table20
# Out:
#    review_scores_value  frequency
# 0      Valor Excelente       4729
# 1    Valor Excepcional       2390
# 2       Valor Superior       2023
# 3       Valor Muy Alto       1280
# 4      Valor Destacado       1143
# 5           Valor Alto       1015
# 6        Valor Notable        607
# 7          Valor Medio        468
# 8          Valor Bueno        361
# 9       Valor Moderado        222
# 10          Valor Bajo        181
# 11     Valor Aceptable        150
# 12      Valor Muy Bajo         73

# %%
#Ppoenr index para que tome como datos lo que queremos gráficar
filtro_index20 = table20.set_index('review_scores_value')
filtro_index20
# Out:
#                      frequency
# review_scores_value
# Valor Excelente           4729
# Valor Excepcional         2390
# Valor Superior            2023
# Valor Muy Alto            1280
# Valor Destacado           1143
# Valor Alto                1015
# Valor Notable              607
# Valor Medio                468
# Valor Bueno                361
# Valor Moderado             222
# Valor Bajo                 181
# Valor Aceptable            150
# Valor Muy Bajo              73

# %%
filtro_index20.plot(kind = 'bar', width = 0.8, figsize=(10,4), color="pink")
plt.title('Herramientas de relación con los clientes')
plt.xlabel('Tipo de valor en el puntaje')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
filtro_index20.plot(kind='area', figsize =(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='review_scores_value'>

# %%
filtro_index20['frequency'].plot(kind='pie', figsize =(15,10), shadow = True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>
